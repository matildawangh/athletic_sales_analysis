# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
data_2020 = pd.read_csv('Resources/athletic_sales_2020.csv')
data_2021 = pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
data_2020
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
data_2021
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
data_2020.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
data_2021.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
combined_data = pd.concat([data_2020, data_2021], axis=0)

# Reset the index
combined_data.reset_index(drop=True, inplace=True)
combined_data
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640       Amazon      1185732     12/31/21  Northeast         Maine
# 9641       Amazon      1185732     12/31/21  Northeast         Maine
# 9642  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
has_null_value = combined_data.isnull().any()
has_null_value
# Out:
# retailer            False
# retailer_id         False
# invoice_date        False
# region              False
# state               False
# city                False
# product             False
# price_per_unit      False
# units_sold          False
# total_sales         False
# operating_profit    False
# sales_method        False
# dtype: bool

# %%
# Check the data type of each column
data_types = combined_data.dtypes
data_types
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
combined_data['invoice_date'] = pd.to_datetime(combined_data['invoice_date'])
coverted_data = combined_data.dtypes

# %%
# Confirm that the "invoice_date" data type has been changed.
coverted_data
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".


groupby_data = combined_data.groupby(['region', 'state', 'city'])[['units_sold']].sum()
                            
# Show the top 5 results.
groupby_data_sorted = groupby_data.sort_values(by='units_sold', ascending=False)  
groupby_data_sorted
# Out:
#                                          units_sold
# region    state          city
# Northeast New York       New York            111954
# South     Texas          Houston              90322
# West      California     San Francisco        85478
#                          Los Angeles          76384
# Southeast Florida        Miami                73135
#           South Carolina Charleston           72610
# South     Texas          Dallas               69178
#           Tennessee      Knoxville            66077
# West      Idaho          Boise                63827
# South     Alabama        Birmingham           63327
# Southeast North Carolina Charlotte            62936
#           Florida        Orlando              60295
# South     Louisiana      New Orleans          57615
# Northeast New York       Albany               57186
# South     Mississippi    Jackson              56814
# Southeast Georgia        Atlanta              56391
# ...

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
pivot_sales = pd.pivot_table(combined_data,values='units_sold', index=['region', 'state', 'city'], aggfunc='sum').reset_index()
# Rename the "units_sold" column to "Total_Products_Sold"
pivot_sales.rename(columns={'units_sold': 'Total_Products_Sold'}, inplace=True)

# # Show the top 5 results
pivot_sales_top5 = pivot_sales.nlargest(5, 'Total_Products_Sold')
pivot_sales_top5
# Out:
#        region       state           city  Total_Products_Sold
# 21  Northeast    New York       New York               111954
# 33      South       Texas        Houston                90322
# 44       West  California  San Francisco                85478
# 43       West  California    Los Angeles                76384
# 34  Southeast     Florida          Miami                73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_total_sales = combined_data.groupby(['region', 'state', 'city'])['total_sales'].sum().reset_index()
grouped_total_sales.rename(columns={'total_sales': 'Total Sales'}, inplace=True)
# Show the top 5 results.
grouped_total_sales_top5 = grouped_total_sales.nlargest(5, 'Total Sales')
grouped_total_sales_top5
# Out:
#        region           state           city  Total Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
pivot_table_total_sales = pd.pivot_table(combined_data, index=['region', 'state', 'city'],values='total_sales', aggfunc='sum').reset_index()

# Optional: Rename the "total_sales" column to "Total Sales"
pivot_table_total_sales.rename(columns={'total_sales':'Total Sales'}, inplace=True)

# Show the top 5 results.
pivot_table_total_sales_top5= pivot_table_total_sales.nlargest(5,'Total Sales')
pivot_table_total_sales_top5
# Out:
#        region           state           city  Total Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_total_sales_with_retail = combined_data.groupby(['retailer', 'region', 'state', 'city'])['total_sales'].sum().reset_index()

grouped_total_sales_with_retail.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# # Get the top 5 results by total sales
top5_total_sales = grouped_total_sales_with_retail.nlargest(5, 'Total Sales')
# # Show the top 5 results.

top5_total_sales
# Out:
#         retailer     region           state           city  Total Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# # Show the total sales for the products sold for each retailer, region, state, and city.
# pivot_table_total_sales_with_resale = pd.pivot_table(combined_data, 
#                                          index=['retailer', 'region', 'state', 'city'], 
#                                          values='total_sales', 
#                                          aggfunc='sum').reset_index()
# pivot_table_total_sales_with_resale.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# # Optional: Rename the "total_sales" column to "Total Sales"
# # Show the top 5 results.
# pivot_table_total_sales_with_resale_top5 = pivot_table_total_sales_with_resale.nlargest(5,'Total Sales')
# pivot_table_total_sales_with_resale_top5

# top5_total_sales = grouped_total_sales_with_retail.nlargest(5, 'Total Sales')
# Out:
#         retailer     region           state           city  Total Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
womens_footwear_sales = combined_data[combined_data['product'] == "Women's Athletic Footwear"]
womens_footwear_sales
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 21    Foot Locker      1185732   2020-01-04  Northeast      New York
# 22    Foot Locker      1185732   2020-01-04  Northeast      New York
# 23    Foot Locker      1185732   2020-01-04  Northeast      New York
# 26      West Gear      1128299   2020-01-05  Northeast  Pennsylvania
# 27      West Gear      1128299   2020-01-05  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9633  Foot Locker      1185732   2021-12-30  Northeast  Pennsylvania
# 9634  Foot Locker      1185732   2021-12-30  Northeast  Pennsylvania
# 9635       Amazon      1185732   2021-12-30  Northeast         Maine
# 9636       Amazon      1185732   2021-12-30  Northeast         Maine
# 9637  Foot Locker      1185732   2021-12-30  Northeast  Pennsylvania
#
#               city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.

# Filter for Women's Athletic Footwear
womens_footwear_sales = combined_data[combined_data['product'] == "Women's Athletic Footwear"]

# Group by retailer, region, state, and city, then sum the units sold
grouped_womens_footwear_sales = womens_footwear_sales.groupby(['retailer', 'region', 'state', 'city'])['units_sold'].sum().reset_index()

# Rename the "units_sold" column
grouped_womens_footwear_sales.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'}, inplace=True)

# Get the top 5 results by Womens_Footwear_Units_Sold
top5_womens_footwear_sales = grouped_womens_footwear_sales.nlargest(5, 'Womens_Footwear_Units_Sold')

top5_womens_footwear_sales
# Out:
#           retailer     region           state           city  \
# 101      West Gear       West      California  San Francisco
# 22     Foot Locker  Northeast        New York       New York
# 49          Kohl's       West      California    Los Angeles
# 33     Foot Locker  Southeast  South Carolina     Charleston
# 68   Sports Direct      South           Texas         Dallas
#
#      Womens_Footwear_Units_Sold
# 101                       12107
# 22                        10996
# 49                        10826
# 33                         8814
# 68                         8790

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.


# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.



# Filter for Women's Athletic Footwear
womens_footwear_sales = combined_data[combined_data['product'] == "Women's Athletic Footwear"]

# Create a pivot table to sum units sold, indexed by retailer, region, state, and city
pivot_womens_footwear_sales = pd.pivot_table(
    womens_footwear_sales, 
    values='units_sold', 
    index=['retailer', 'region', 'state', 'city'], 
    aggfunc='sum'
).rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'})

# Sort the pivot table to get the top 5 results by Womens_Footwear_Units_Sold
top5_womens_footwear_sales = pivot_womens_footwear_sales.nlargest(5, 'Womens_Footwear_Units_Sold')

top5_womens_footwear_sales
# Out:
#                                                       Womens_Footwear_Units_Sold
# retailer      region    state          city
# West Gear     West      California     San Francisco                       12107
# Foot Locker   Northeast New York       New York                            10996
# Kohl's        West      California     Los Angeles                         10826
# Foot Locker   Southeast South Carolina Charleston                           8814
# Sports Direct South     Texas          Dallas                               8790

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
pivot_table_by_date = pd.pivot_table(combined_data, 
                                     index='invoice_date', 
                                     values='total_sales', 
                                     aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"
pivot_table_by_date.rename(columns={'total_sales': 'Total Sales'}, inplace=True)


# Show the table.
pivot_table_by_date
# Out:
#               Total Sales
# invoice_date
# 2020-01-01         845141
# 2020-01-02         689410
# 2020-01-03         632573
# 2020-01-04         615080
# 2020-01-05         707829
# ...                   ...
# 2021-12-27         602353
# 2021-12-28         301010
# 2021-12-29         211109
# 2021-12-30         167903
# 2021-12-31         198659
#
# [723 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.


# Sort the resampled pivot table in ascending order on "Total Sales".



# Make sure 'invoice_date' is a datetime dtype
combined_data['invoice_date'] = pd.to_datetime(combined_data['invoice_date'])

# Create the initial pivot table
pivot_table_by_date = combined_data.pivot_table(index='invoice_date', values='total_sales', aggfunc='sum')

# Resample the pivot table into daily bins
daily_sales = pivot_table_by_date.resample('D').sum()

# Rename the 'total_sales' column to 'Total Sales'
daily_sales.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# Sort the resampled pivot table in ascending order on "Total Sales"
sorted_daily_sales = daily_sales.sort_values(by='Total Sales', ascending=False)

# Display the sorted resampled pivot table
sorted_daily_sales
# Out:
#               Total Sales
# invoice_date
# 2021-07-16       12261098
# 2021-12-16       10871121
# 2021-06-17       10239903
# 2021-08-17        9517031
# 2021-07-23        7689134
# ...                   ...
# 2020-10-16              0
# 2020-10-15              0
# 2020-10-14              0
# 2020-10-13              0
# 2020-12-31              0
#
# [731 rows x 1 columns]

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.


# Sort the resampled pivot table in ascending order on "Total Sales".
import pandas as pd

# Assuming your DataFrame is named 'combined_data'
# Convert 'invoice_date' to datetime if it's not already
combined_data['invoice_date'] = pd.to_datetime(combined_data['invoice_date'])

# Create a pivot table with 'invoice_date' as the index and 'total_sales' as the values
pivot_table_by_date = combined_data.pivot_table(index='invoice_date', values='total_sales', aggfunc='sum')

# Resample to weekly bins and sum to get total sales for each week
weekly_sales = pivot_table_by_date.resample('W').sum()

# Rename the 'total_sales' column to 'Total Sales' for clarity
weekly_sales.rename(columns={'total_sales': 'Total Sales'}, inplace=True)

# Sort the resampled table in ascending order by 'Total Sales'
sorted_weekly_sales = weekly_sales.sort_values('Total Sales', ascending=False)

# Display the sorted weekly sales
sorted_weekly_sales
# Out:
#               Total Sales
# invoice_date
# 2021-07-11       26271380
# 2021-07-18       24731702
# 2021-12-19       24698535
# 2021-12-12       23250286
# 2021-08-22       22225401
# ...                   ...
# 2020-11-22         927605
# 2020-12-06         739673
# 2020-12-20         590227
# 2020-12-13         466322
# 2020-10-18         251468
#
# [105 rows x 1 columns]
